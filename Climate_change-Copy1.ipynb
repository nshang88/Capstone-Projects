# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
#Read files from the website

# %%
def add(climate_data, url, name):
    data_city= pd.read_table(url, delim_whitespace=True, names=('Month', 'Day', 'Year', name))
    d1=data_city[['Month', 'Day', 'Year']]                       
    data_city['Date']=pd.to_datetime(d1)
    data_city=data_city[['Date',name]]
    climate_data=climate_data.merge(data_city, on = 'Date')
    return climate_data

# %%
N='AK_Anchorage_Temp'
url_1='https://academic.udayton.edu/kissock/http/Weather/gsod95-current/AKANCHOR.txt'
data_Anchorage = pd.read_table(url_1, delim_whitespace=True, names=('Month', 'Day', 'Year', N))
data_Anchorage.head()
# Out:
#    Month  Day  Year  AK_Anchorage_Temp
# 0      1    1  1995               23.2
# 1      1    2  1995               27.6
# 2      1    3  1995               32.0
# 3      1    4  1995               29.3
# 4      1    5  1995               30.1

# %%
data_Anchorage.shape
# Out:
# (9265, 4)

# %%
date1=data_Anchorage[['Month', 'Day', 'Year']]

# %%
data_Anchorage['Date']=pd.to_datetime(date1)

# %%
data_Anchorage.head()
# Out:
#    Month  Day  Year  AK_Anchorage_Temp       Date
# 0      1    1  1995               23.2 1995-01-01
# 1      1    2  1995               27.6 1995-01-02
# 2      1    3  1995               32.0 1995-01-03
# 3      1    4  1995               29.3 1995-01-04
# 4      1    5  1995               30.1 1995-01-05

# %%
data_Anchorage=data_Anchorage[['Date','AK_Anchorage_Temp' ]]
climate_data=data_Anchorage

# %%
url_2='https://academic.udayton.edu/kissock/http/Weather/gsod95-current/NDFARGO.txt'
climate_data=add(climate_data,url_2, 'ND_Fargo_Temp')

# %%
climate_data.head()
# Out:
#         Date  AK_Anchorage_Temp  ND_Fargo_Temp
# 0 1995-01-01               23.2            5.2
# 1 1995-01-02               27.6           10.1
# 2 1995-01-03               32.0           -3.8
# 3 1995-01-04               29.3           -6.3
# 4 1995-01-05               30.1            8.4

# %%
url_3=['https://academic.udayton.edu/kissock/http/Weather/gsod95-current/FLWPALMB.txt', 'FL_West_Palm_Beach_Temp']
url_4= ['https://academic.udayton.edu/kissock/http/Weather/gsod95-current/VTBURLIN.txt', 'Vermont_Burlington_Temp']
url_5= ['https://academic.udayton.edu/kissock/http/Weather/gsod95-current/TXELPASO.txt', 'TX_El_Paso_Temp']
url_6 = ['https://academic.udayton.edu/kissock/http/Weather/gsod95-current/WYCHEYEN.txt', 'Wyoming_Cheyenne_Temp']
url_7= ['https://academic.udayton.edu/kissock/http/Weather/gsod95-current/CASANFRA.txt','San_Francisco_Temp']
url_8= ['https://academic.udayton.edu/kissock/http/Weather/gsod95-current/OHCLEVEL.txt','Cleveland_Temp']
url_9= ['https://academic.udayton.edu/kissock/http/Weather/gsod95-current/WIMILWAU.txt','Milwaukee_Temp']
url_10=['https://academic.udayton.edu/kissock/http/Weather/gsod95-current/HIHONOLU.txt', 'Honolulu_Temp']
url_11=['https://academic.udayton.edu/kissock/http/weather/gsod95-current/EGCAIRO.txt', 'Egypt_Cairo']
url_12= ['https://academic.udayton.edu/kissock/http/weather/gsod95-current/INDELHI.txt','India_Delhi']
url_13= ['https://academic.udayton.edu/kissock/http/weather/gsod95-current/CIBIEJNG.txt','China_Beijing']
url_14= ['https://academic.udayton.edu/kissock/http/weather/gsod95-current/SRSINGAP.txt','Singapore_Temp']
url_15=['https://academic.udayton.edu/kissock/http/weather/gsod95-current/NZACKLND.txt', 'New_Zealand Auckland']
url_16=['https://academic.udayton.edu/kissock/http/weather/gsod95-current/RSMOSCOW.txt', 'Russia_Moscow']
url_17=['https://academic.udayton.edu/kissock/http/weather/gsod95-current/AGBUENOS.txt', 'Argentina Buenos_Aires']
url_18=['https://academic.udayton.edu/kissock/http/weather/gsod95-current/PRLIMA.txt','Peru_Lima']

city_list=[url_3, url_4, url_5, url_6, url_7, url_8, url_9, url_10,url_11, url_12, url_13, url_14,url_15, url_16, url_17, url_18] # url_19, url_20]

# %%
for url in city_list:
    climate_data=add(climate_data, url[0], url[1])
climate_data.shape
# Out:
# (7627, 19)

# %%
climate_data.head(4)
# Out:
#         Date  AK_Anchorage_Temp  ND_Fargo_Temp  FL_West_Palm_Beach_Temp  \
# 0 1995-01-01               23.2            5.2                     69.7
# 1 1995-01-02               27.6           10.1                     68.7
# 2 1995-01-03               32.0           -3.8                     68.9
# 3 1995-01-04               29.3           -6.3                     68.0
#
#    Vermont_Burlington_Temp  TX_El_Paso_Temp  Wyoming_Cheyenne_Temp  \
# 0                     31.0             39.9                    8.8
# 1                     30.1             37.0                   19.0
# 2                     25.9             41.3                   11.3
# 3                     23.1             40.1                    5.0
#
#    San_Francisco_Temp  Cleveland_Temp  Milwaukee_Temp  Honolulu_Temp  \
# 0                46.7            39.9            23.8           71.3
# 1                47.3            23.5            14.5           72.5
# 2                49.6            21.4            15.5           73.2
# 3                50.0            15.2             3.9           71.9
#
#    Egypt_Cairo  India_Delhi  China_Beijing  Singapore_Temp  \
# 0         59.2         50.7           28.0            81.1
# 1         57.5         52.1           29.0            81.7
# 2         57.4         53.8           29.9            82.4
# 3         59.3         53.7           34.5            82.6
#
#    New_Zealand Auckland  Russia_Moscow  Argentina Buenos_Aires  Peru_Lima
# 0                  63.6           32.3                    82.4       73.1
# 1                  63.8           31.7                    75.1       74.0
# 2                  59.2           26.8                    73.7       73.6
# 3                  61.2           15.9                    77.1       74.5

# %%
climate_data=climate_data.set_index(['Date'])
climate_data.head()
# Out:
#             AK_Anchorage_Temp  ND_Fargo_Temp  FL_West_Palm_Beach_Temp  \
# Date
# 1995-01-01               23.2            5.2                     69.7
# 1995-01-02               27.6           10.1                     68.7
# 1995-01-03               32.0           -3.8                     68.9
# 1995-01-04               29.3           -6.3                     68.0
# 1995-01-05               30.1            8.4                     64.5
#
#             Vermont_Burlington_Temp  TX_El_Paso_Temp  Wyoming_Cheyenne_Temp  \
# Date
# 1995-01-01                     31.0             39.9                    8.8
# 1995-01-02                     30.1             37.0                   19.0
# 1995-01-03                     25.9             41.3                   11.3
# 1995-01-04                     23.1             40.1                    5.0
# 1995-01-05                     12.0             40.9                   18.9
#
#             San_Francisco_Temp  Cleveland_Temp  Milwaukee_Temp  Honolulu_Temp  \
# Date
# 1995-01-01                46.7            39.9            23.8           71.3
# 1995-01-02                47.3            23.5            14.5           72.5
# 1995-01-03                49.6            21.4            15.5           73.2
# 1995-01-04                50.0            15.2             3.9           71.9
# 1995-01-05                50.8            10.5             6.1           70.4
#
#             Egypt_Cairo  India_Delhi  China_Beijing  Singapore_Temp  \
# Date
# 1995-01-01         59.2         50.7           28.0            81.1
# 1995-01-02         57.5         52.1           29.0            81.7
# 1995-01-03         57.4         53.8           29.9            82.4
# 1995-01-04         59.3         53.7           34.5            82.6
# 1995-01-05         58.8         54.5           36.6            82.4
#
#             New_Zealand Auckland  Russia_Moscow  Argentina Buenos_Aires  \
# Date
# 1995-01-01                  63.6           32.3                    82.4
# 1995-01-02                  63.8           31.7                    75.1
# 1995-01-03                  59.2           26.8                    73.7
# 1995-01-04                  61.2           15.9                    77.1
# 1995-01-05                  64.0           23.8                    79.5
#
#             Peru_Lima
# Date
# 1995-01-01       73.1
# 1995-01-02       74.0
# 1995-01-03       73.6
# 1995-01-04       74.5
# 1995-01-05       73.4

# %%
climate_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7627 entries, 1995-01-01 to 2015-11-18
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AK_Anchorage_Temp        7627 non-null   float64
#  1   ND_Fargo_Temp            7627 non-null   float64
#  2   FL_West_Palm_Beach_Temp  7627 non-null   float64
#  3   Vermont_Burlington_Temp  7627 non-null   float64
#  4   TX_El_Paso_Temp          7627 non-null   float64
#  5   Wyoming_Cheyenne_Temp    7627 non-null   float64
#  6   San_Francisco_Temp       7627 non-null   float64
#  7   Cleveland_Temp           7627 non-null   float64
#  8   Milwaukee_Temp           7627 non-null   float64
#  9   Honolulu_Temp            7627 non-null   float64
#  10  Egypt_Cairo              7627 non-null   float64
#  11  India_Delhi              7627 non-null   float64
#  12  China_Beijing            7627 non-null   float64
#  13  Singapore_Temp           7627 non-null   float64
#  14  New_Zealand Auckland     7627 non-null   float64
#  15  Russia_Moscow            7627 non-null   float64
#  16  Argentina Buenos_Aires   7627 non-null   float64
#  17  Peru_Lima                7627 non-null   float64
# dtypes: float64(18)
# memory usage: 1.1 MB

# %%
np.percentile(climate_data['AK_Anchorage_Temp'], [2.5, 97.5])
# Out:
# array([ 2.365, 62.6  ])

# %%
# Find the outliers in the temperature data

# %%
climate_data[climate_data['AK_Anchorage_Temp']<-60]
# Out:
#             AK_Anchorage_Temp  ND_Fargo_Temp  FL_West_Palm_Beach_Temp  \
# Date
# 1998-12-24              -99.0          -99.0                    -99.0
# 1998-12-25              -99.0          -99.0                    -99.0
# 1998-12-30              -99.0          -99.0                    -99.0
# 1998-12-31              -99.0          -99.0                    -99.0
# 1999-01-10              -99.0          -99.0                    -99.0
# 2002-06-18              -99.0          -99.0                    -99.0
# 2002-06-19              -99.0          -99.0                    -99.0
# 2002-06-20              -99.0          -99.0                    -99.0
# 2002-06-21              -99.0          -99.0                    -99.0
# 2007-08-28              -99.0          -99.0                    -99.0
# 2008-08-18              -99.0          -99.0                     78.4
# 2008-09-24              -99.0          -99.0                    -99.0
# 2009-04-09              -99.0          -99.0                    -99.0
#
#             Vermont_Burlington_Temp  TX_El_Paso_Temp  Wyoming_Cheyenne_Temp  \
# Date
# 1998-12-24                    -99.0            -99.0                  -99.0
# 1998-12-25                    -99.0            -99.0                  -99.0
# 1998-12-30                    -99.0            -99.0                  -99.0
# 1998-12-31                    -99.0            -99.0                  -99.0
# 1999-01-10                    -99.0            -99.0                  -99.0
# 2002-06-18                    -99.0            -99.0                  -99.0
# 2002-06-19                    -99.0            -99.0                  -99.0
# 2002-06-20                    -99.0            -99.0                  -99.0
# 2002-06-21                    -99.0            -99.0                  -99.0
# 2007-08-28                    -99.0            -99.0                  -99.0
# 2008-08-18                     72.0             76.8                   60.7
# 2008-09-24                    -99.0            -99.0                  -99.0
# 2009-04-09                    -99.0            -99.0                  -99.0
#
# New_Zealand Auckland       43
# Russia_Moscow              14
# Argentina Buenos_Aires     19
# Peru_Lima                  21
# dtype: int64

# %%
climate_data.describe()
# Out:
#        AK_Anchorage_Temp  ND_Fargo_Temp  FL_West_Palm_Beach_Temp  \
# count        7614.000000    7602.000000              7602.000000
# mean           37.721907      42.970166                75.555670
# std            16.985082      24.187310                 7.549624
# min           -19.600000     -29.500000                38.500000
# 25%            25.500000      24.925000                71.900000
# 50%            38.350000      45.500000                77.200000
# 75%            53.100000      64.175000                81.200000
# max            75.300000      91.400000                89.300000
#
#        Vermont_Burlington_Temp  TX_El_Paso_Temp  Wyoming_Cheyenne_Temp  \
# count              7605.000000      7608.000000            7611.000000
# mean                 47.055069        66.203444              46.850388
# std                  19.887238        15.364580              17.318017
# min                 -14.100000         8.400000             -12.000000
# 25%                  32.200000        53.400000              34.100000
# 50%                  48.400000        68.200000              46.600000
# 75%                  64.400000        79.600000              61.700000
# max                  87.400000        95.000000              84.700000
#
#        San_Francisco_Temp  Cleveland_Temp  Milwaukee_Temp  Honolulu_Temp  \
# count         7591.000000     7613.000000     7572.000000    7609.000000
# mean            57.258912       51.422317       48.608875      77.285281
# std              5.653676       18.453356       19.220724       3.392106
# min             38.300000       -5.900000      -16.600000      65.700000
# 25%             53.200000       36.400000       33.700000      74.800000
# 50%             57.400000       53.000000       49.000000      77.500000
# 75%             61.000000       67.700000       65.400000      80.000000
# max             80.800000       87.200000       92.200000      87.200000
#
#        Egypt_Cairo  India_Delhi  China_Beijing  Singapore_Temp  \
# count  7607.000000  7591.000000    7614.000000     7613.000000
# mean     72.526660    76.804703      55.335763       82.133561
# std      10.468613    13.197400      20.032675        2.165280
# min      45.200000    43.900000       6.800000       74.000000
# 25%      63.000000    65.200000      36.600000       80.600000
# 50%      73.600000    80.600000      57.800000       82.200000
# 75%      81.800000    87.300000      73.800000       83.800000
# max      98.900000   103.700000      92.900000       88.500000
#
#        New_Zealand Auckland  Russia_Moscow  Argentina Buenos_Aires  \
# count           7584.000000    7613.000000             7608.000000
# mean              59.675949      42.357783               62.683636
# std                6.436488      19.480276               10.689108
# min               41.100000     -20.400000               35.300000
# 25%               54.900000      28.700000               54.500000
# 50%               59.500000      42.500000               63.050000
# 75%               64.900000      59.000000               71.200000
# max               75.400000      87.300000               90.900000
#
#          Peru_Lima
# count  7606.000000
# mean     67.090757
# std       4.976993
# min      57.500000
# 25%      62.700000
# 50%      66.600000
# 75%      71.200000
# max      81.800000

# %%
#Show the data on graph to make sure there is no outliers.

# %%
fig, ax = plt.subplots(figsize=(16,12))
plt.scatter(climate_data.index[0:1500],climate_data['AK_Anchorage_Temp'][0:1500], s=10, c='r',label='Anchorage' )
plt.scatter(climate_data.index[0:1500],climate_data['ND_Fargo_Temp'][0:1500],s=10, c='b',label='Fargo' )
ax.set_xlabel('Date')
ax.set_ylabel('Temperature')
plt.legend(loc='upper left')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(18,12))
ax.scatter(climate_data.index ,climate_data['AK_Anchorage_Temp'],s=10, c='b', label='Anchorage')
ax.set_xlabel('Date')
ax.set_ylabel('Temperature')
plt.legend(loc='upper left')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(24,12))
ax.plot(climate_data.index ,climate_data['ND_Fargo_Temp'],c='g', label='Fargo')
ax.set_xlabel('Date')
ax.set_ylabel('Temperature')
plt.legend(loc='upper left')
plt.show()
